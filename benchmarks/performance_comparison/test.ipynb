# %%
from ultralytics import YOLO
import cv2
import time
import csv
import matplotlib.pyplot as plt
import torch

def process_video_on_gpu(video_path, output_path, csv_file, batch_size=16):
    # Load YOLO model
    model = YOLO("yolo11x.pt").to("cuda")  # Ensure the model runs on GPU

    # Initialize video input and output
    cap = cv2.VideoCapture(video_path)
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

    # Write CSV headers
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Time (s)", "People Count"])

    frame_count = 0
    start_time = time.time()
    timestamps = []
    people_counts = []
    frames_batch = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_count += 1
        current_time = frame_count / fps
        timestamps.append(current_time)
        frames_batch.append(frame)

        # Process frames in batches
        if len(frames_batch) == batch_size:
            process_batch(frames_batch, current_time, model, out, csv_file, people_counts)
            frames_batch = []

    # Process remaining frames
    if frames_batch:
        process_batch(frames_batch, current_time, model, out, csv_file, people_counts)

    cap.release()
    out.release()

    # Save graph
    plt.figure(figsize=(10, 6))
    plt.plot(timestamps, people_counts, marker='o', color='b', label="People Count")
    plt.title(f"People Count Over Time - {video_path}")
    plt.xlabel("Time (s)")
    plt.ylabel("Number of People")
    plt.grid(True)
    plt.legend()
    graph_path = csv_file.replace('.csv', '_graph.png')
    plt.savefig(graph_path)
    plt.close()

    total_time = time.time() - start_time
    print(f"Processed {video_path} - Total Frames: {frame_count}, Total Time: {total_time:.2f} seconds")

def process_batch(frames_batch, current_time, model, out, csv_file, people_counts):
    # Resize frames to be divisible by 32
    resized_frames = [cv2.resize(frame, (640, 640)) for frame in frames_batch]

    # Convert frames to tensors and normalize
    frames_tensor = [torch.tensor(frame).permute(2, 0, 1).unsqueeze(0).float().to("cuda") for frame in resized_frames]
    batch_tensor = torch.cat(frames_tensor) / 255.0  # Normalize the images

    # Run YOLO inference
    results = model(batch_tensor)

    for i, frame in enumerate(frames_batch):
        # Extract people detections for each frame
        people_count = sum(1 for detection in results[i].boxes if int(detection.cls) == 0)
        people_counts.append(people_count)

        # Log to CSV
        with open(csv_file, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([current_time, people_count])

        # Draw bounding boxes and count on the frame
        for detection in results[i].boxes:
            if int(detection.cls) == 0:
                bbox = detection.xyxy[0].cpu().numpy()
                cv2.rectangle(frame, (int(bbox[0]), int(bbox[1])), (int(bbox[2]), int(bbox[3])), (0, 255, 0), 2)

        cv2.putText(frame, f"People Count: {people_count}", (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
        out.write(frame)


def main():
    videos = [
        {"input": "video (1).mp4", "output": "output (1).mp4", "csv": "output (1).csv"},
        {"input": "video (2).mp4", "output": "output (2).mp4", "csv": "output (2).csv"},
        {"input": "video (3).mp4", "output": "output (3).mp4", "csv": "output (3).csv"},
        {"input": "video (4).mp4", "output": "output (4).mp4", "csv": "output (4).csv"},
        {"input": "video (5).mp4", "output": "output (5).mp4", "csv": "output (5).csv"},
        {"input": "video (6).mp4", "output": "output (6).mp4", "csv": "output (6).csv"},
        {"input": "video (7).mp4", "output": "output (7).mp4", "csv": "output (7).csv"},
        {"input": "video (8).mp4", "output": "output (8).mp4", "csv": "output (8).csv"},
        {"input": "video (9).mp4", "output": "output (9).mp4", "csv": "output (9).csv"},
        {"input": "video (10).mp4", "output": "output (10).mp4", "csv": "output (10).csv"}
    ]

    for video in videos:
        process_video_on_gpu(video["input"], video["output"], video["csv"])


if __name__ == "__main__":
    main()
# Out:
# 0: 640x640 (no detections), 51.8ms
# 1: 640x640 (no detections), 51.8ms
# 2: 640x640 (no detections), 51.8ms
# 3: 640x640 (no detections), 51.8ms
# 4: 640x640 (no detections), 51.8ms
# 5: 640x640 (no detections), 51.8ms
# 6: 640x640 (no detections), 51.8ms
# 7: 640x640 (no detections), 51.8ms
# 8: 640x640 (no detections), 51.8ms
# 9: 640x640 (no detections), 51.8ms
# 10: 640x640 (no detections), 51.8ms
# 11: 640x640 (no detections), 51.8ms
# 12: 640x640 (no detections), 51.8ms
# 13: 640x640 (no detections), 51.8ms
# 14: 640x640 (no detections), 51.8ms
# 15: 640x640 (no detections), 51.8ms
# Speed: 0.0ms preprocess, 51.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 53.7ms
# 1: 640x640 (no detections), 53.7ms
# 2: 640x640 (no detections), 53.7ms
# 3: 640x640 (no detections), 53.7ms
# 4: 640x640 (no detections), 53.7ms
# 5: 640x640 (no detections), 53.7ms
# 6: 640x640 (no detections), 53.7ms
# 7: 640x640 (no detections), 53.7ms
# 8: 640x640 (no detections), 53.7ms
# 9: 640x640 (no detections), 53.7ms
# 10: 640x640 (no detections), 53.7ms
# 11: 640x640 (no detections), 53.7ms
# 12: 640x640 (no detections), 53.7ms
# 13: 640x640 (no detections), 53.7ms
# 14: 640x640 (no detections), 53.7ms
# 15: 640x640 (no detections), 53.7ms
# Speed: 0.0ms preprocess, 53.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.1ms
# 1: 640x640 (no detections), 56.1ms
# 2: 640x640 (no detections), 56.1ms
# 3: 640x640 (no detections), 56.1ms
# 4: 640x640 (no detections), 56.1ms
# 5: 640x640 (no detections), 56.1ms
# 6: 640x640 (no detections), 56.1ms
# 7: 640x640 (no detections), 56.1ms
# 8: 640x640 (no detections), 56.1ms
# 9: 640x640 (no detections), 56.1ms
# 10: 640x640 (no detections), 56.1ms
# 11: 640x640 (no detections), 56.1ms
# 12: 640x640 (no detections), 56.1ms
# 13: 640x640 (no detections), 56.1ms
# 14: 640x640 (no detections), 56.1ms
# 15: 640x640 (no detections), 56.1ms
# Speed: 0.0ms preprocess, 56.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.0ms
# 1: 640x640 (no detections), 56.0ms
# 2: 640x640 (no detections), 56.0ms
# 3: 640x640 (no detections), 56.0ms
# 4: 640x640 (no detections), 56.0ms
# 5: 640x640 (no detections), 56.0ms
# 6: 640x640 (no detections), 56.0ms
# 7: 640x640 (no detections), 56.0ms
# 8: 640x640 (no detections), 56.0ms
# 9: 640x640 (no detections), 56.0ms
# 10: 640x640 (no detections), 56.0ms
# 11: 640x640 (no detections), 56.0ms
# 12: 640x640 (no detections), 56.0ms
# 13: 640x640 (no detections), 56.0ms
# 14: 640x640 (no detections), 56.0ms
# 15: 640x640 (no detections), 56.0ms
# Speed: 0.0ms preprocess, 56.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.5ms
# 1: 640x640 (no detections), 56.5ms
# 2: 640x640 (no detections), 56.5ms
# 3: 640x640 (no detections), 56.5ms
# 4: 640x640 (no detections), 56.5ms
# 5: 640x640 (no detections), 56.5ms
# 6: 640x640 (no detections), 56.5ms
# 7: 640x640 (no detections), 56.5ms
# 8: 640x640 (no detections), 56.5ms
# 9: 640x640 (no detections), 56.5ms
# 10: 640x640 (no detections), 56.5ms
# 11: 640x640 (no detections), 56.5ms
# 12: 640x640 (no detections), 56.5ms
# 13: 640x640 (no detections), 56.5ms
# 14: 640x640 (no detections), 56.5ms
# 15: 640x640 (no detections), 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.4ms
# 1: 640x640 (no detections), 56.4ms
# 2: 640x640 (no detections), 56.4ms
# 3: 640x640 (no detections), 56.4ms
# 4: 640x640 (no detections), 56.4ms
# 5: 640x640 (no detections), 56.4ms
# 6: 640x640 (no detections), 56.4ms
# 7: 640x640 (no detections), 56.4ms
# 8: 640x640 (no detections), 56.4ms
# 9: 640x640 (no detections), 56.4ms
# 10: 640x640 (no detections), 56.4ms
# 11: 640x640 (no detections), 56.4ms
# 12: 640x640 (no detections), 56.4ms
# 13: 640x640 (no detections), 56.4ms
# 14: 640x640 (no detections), 56.4ms
# 15: 640x640 (no detections), 56.4ms
# Speed: 0.0ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.5ms
# 1: 640x640 (no detections), 56.5ms
# 2: 640x640 (no detections), 56.5ms
# 3: 640x640 (no detections), 56.5ms
# 4: 640x640 (no detections), 56.5ms
# 5: 640x640 (no detections), 56.5ms
# 6: 640x640 (no detections), 56.5ms
# 7: 640x640 (no detections), 56.5ms
# 8: 640x640 (no detections), 56.5ms
# 9: 640x640 (no detections), 56.5ms
# 10: 640x640 (no detections), 56.5ms
# 11: 640x640 (no detections), 56.5ms
# 12: 640x640 (no detections), 56.5ms
# 13: 640x640 (no detections), 56.5ms
# 14: 640x640 (no detections), 56.5ms
# 15: 640x640 (no detections), 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.4ms
# 1: 640x640 (no detections), 56.4ms
# 2: 640x640 (no detections), 56.4ms
# 3: 640x640 (no detections), 56.4ms
# 4: 640x640 (no detections), 56.4ms
# 5: 640x640 (no detections), 56.4ms
# 6: 640x640 (no detections), 56.4ms
# 7: 640x640 (no detections), 56.4ms
# 8: 640x640 (no detections), 56.4ms
# 9: 640x640 (no detections), 56.4ms
# 10: 640x640 (no detections), 56.4ms
# 11: 640x640 (no detections), 56.4ms
# 12: 640x640 (no detections), 56.4ms
# 13: 640x640 (no detections), 56.4ms
# 14: 640x640 (no detections), 56.4ms
# 15: 640x640 (no detections), 56.4ms
# Speed: 0.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.4ms
# 1: 640x640 (no detections), 56.4ms
# 2: 640x640 (no detections), 56.4ms
# 3: 640x640 (no detections), 56.4ms
# 4: 640x640 (no detections), 56.4ms
# 5: 640x640 (no detections), 56.4ms
# 6: 640x640 (no detections), 56.4ms
# 7: 640x640 (no detections), 56.4ms
# 8: 640x640 (no detections), 56.4ms
# 9: 640x640 (no detections), 56.4ms
# 10: 640x640 (no detections), 56.4ms
# 11: 640x640 (no detections), 56.4ms
# 12: 640x640 (no detections), 56.4ms
# 13: 640x640 (no detections), 56.4ms
# 14: 640x640 (no detections), 56.4ms
# 15: 640x640 (no detections), 56.4ms
# Speed: 0.0ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.4ms
# 1: 640x640 (no detections), 56.4ms
# 2: 640x640 (no detections), 56.4ms
# 3: 640x640 (no detections), 56.4ms
# 4: 640x640 (no detections), 56.4ms
# 5: 640x640 (no detections), 56.4ms
# 6: 640x640 (no detections), 56.4ms
# 7: 640x640 (no detections), 56.4ms
# 8: 640x640 (no detections), 56.4ms
# 9: 640x640 (no detections), 56.4ms
# 10: 640x640 (no detections), 56.4ms
# 11: 640x640 (no detections), 56.4ms
# 12: 640x640 (no detections), 56.4ms
# 13: 640x640 (no detections), 56.4ms
# 14: 640x640 (no detections), 56.4ms
# 15: 640x640 (no detections), 56.4ms
# Speed: 0.0ms preprocess, 56.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.5ms
# 1: 640x640 (no detections), 56.5ms
# 2: 640x640 (no detections), 56.5ms
# 3: 640x640 (no detections), 56.5ms
# 4: 640x640 (no detections), 56.5ms
# 5: 640x640 (no detections), 56.5ms
# 6: 640x640 (no detections), 56.5ms
# 7: 640x640 (no detections), 56.5ms
# 8: 640x640 (no detections), 56.5ms
# 9: 640x640 (no detections), 56.5ms
# 10: 640x640 (no detections), 56.5ms
# 11: 640x640 (no detections), 56.5ms
# 12: 640x640 (no detections), 56.5ms
# 13: 640x640 (no detections), 56.5ms
# 14: 640x640 (no detections), 56.5ms
# 15: 640x640 (no detections), 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.9ms
# 1: 640x640 (no detections), 56.9ms
# 2: 640x640 (no detections), 56.9ms
# 3: 640x640 (no detections), 56.9ms
# 4: 640x640 (no detections), 56.9ms
# 5: 640x640 (no detections), 56.9ms
# 6: 640x640 (no detections), 56.9ms
# 7: 640x640 (no detections), 56.9ms
# 8: 640x640 (no detections), 56.9ms
# 9: 640x640 (no detections), 56.9ms
# 10: 640x640 (no detections), 56.9ms
# 11: 640x640 (no detections), 56.9ms
# 12: 640x640 (no detections), 56.9ms
# 13: 640x640 (no detections), 56.9ms
# 14: 640x640 (no detections), 56.9ms
# 15: 640x640 (no detections), 56.9ms
# Speed: 0.0ms preprocess, 56.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.5ms
# 1: 640x640 (no detections), 56.5ms
# 2: 640x640 (no detections), 56.5ms
# 3: 640x640 (no detections), 56.5ms
# 4: 640x640 (no detections), 56.5ms
# 5: 640x640 (no detections), 56.5ms
# 6: 640x640 (no detections), 56.5ms
# 7: 640x640 (no detections), 56.5ms
# 8: 640x640 (no detections), 56.5ms
# 9: 640x640 (no detections), 56.5ms
# 10: 640x640 (no detections), 56.5ms
# 11: 640x640 (no detections), 56.5ms
# 12: 640x640 (no detections), 56.5ms
# 13: 640x640 (no detections), 56.5ms
# 14: 640x640 (no detections), 56.5ms
# 15: 640x640 (no detections), 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.7ms
# 1: 640x640 (no detections), 56.7ms
# 2: 640x640 (no detections), 56.7ms
# 3: 640x640 (no detections), 56.7ms
# 4: 640x640 (no detections), 56.7ms
# 5: 640x640 (no detections), 56.7ms
# 6: 640x640 (no detections), 56.7ms
# 7: 640x640 (no detections), 56.7ms
# 8: 640x640 (no detections), 56.7ms
# 9: 640x640 (no detections), 56.7ms
# 10: 640x640 (no detections), 56.7ms
# 11: 640x640 (no detections), 56.7ms
# 12: 640x640 (no detections), 56.7ms
# 13: 640x640 (no detections), 56.7ms
# 14: 640x640 (no detections), 56.7ms
# 15: 640x640 (no detections), 56.7ms
# Speed: 0.0ms preprocess, 56.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 57.2ms
# 1: 640x640 (no detections), 57.2ms
# 2: 640x640 (no detections), 57.2ms
# 3: 640x640 (no detections), 57.2ms
# 4: 640x640 (no detections), 57.2ms
# 5: 640x640 (no detections), 57.2ms
# 6: 640x640 (no detections), 57.2ms
# 7: 640x640 (no detections), 57.2ms
# 8: 640x640 (no detections), 57.2ms
# 9: 640x640 (no detections), 57.2ms
# 10: 640x640 (no detections), 57.2ms
# 11: 640x640 (no detections), 57.2ms
# 12: 640x640 (no detections), 57.2ms
# 13: 640x640 (no detections), 57.2ms
# 14: 640x640 (no detections), 57.2ms
# 15: 640x640 (no detections), 57.2ms
# Speed: 0.0ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.4ms
# 1: 640x640 (no detections), 56.4ms
# 2: 640x640 (no detections), 56.4ms
# 3: 640x640 (no detections), 56.4ms
# 4: 640x640 (no detections), 56.4ms
# 5: 640x640 (no detections), 56.4ms
# 6: 640x640 (no detections), 56.4ms
# 7: 640x640 (no detections), 56.4ms
# 8: 640x640 (no detections), 56.4ms
# 9: 640x640 (no detections), 56.4ms
# 10: 640x640 (no detections), 56.4ms
# 11: 640x640 (no detections), 56.4ms
# 12: 640x640 (no detections), 56.4ms
# 13: 640x640 (no detections), 56.4ms
# 14: 640x640 (no detections), 56.4ms
# 15: 640x640 (no detections), 56.4ms
# Speed: 0.0ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 60.6ms
# 1: 640x640 (no detections), 60.6ms
# 2: 640x640 (no detections), 60.6ms
# 3: 640x640 (no detections), 60.6ms
# 4: 640x640 (no detections), 60.6ms
# 5: 640x640 (no detections), 60.6ms
# 6: 640x640 (no detections), 60.6ms
# 7: 640x640 (no detections), 60.6ms
# 8: 640x640 (no detections), 60.6ms
# 9: 640x640 (no detections), 60.6ms
# 10: 640x640 (no detections), 60.6ms
# 11: 640x640 (no detections), 60.6ms
# 12: 640x640 (no detections), 60.6ms
# 13: 640x640 (no detections), 60.6ms
# 14: 640x640 (no detections), 60.6ms
# 15: 640x640 (no detections), 60.6ms
# Speed: 0.0ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.0ms
# 1: 640x640 (no detections), 56.0ms
# 2: 640x640 (no detections), 56.0ms
# 3: 640x640 (no detections), 56.0ms
# 4: 640x640 (no detections), 56.0ms
# 5: 640x640 (no detections), 56.0ms
# 6: 640x640 (no detections), 56.0ms
# 7: 640x640 (no detections), 56.0ms
# 8: 640x640 (no detections), 56.0ms
# 9: 640x640 (no detections), 56.0ms
# 10: 640x640 (no detections), 56.0ms
# 11: 640x640 (no detections), 56.0ms
# 12: 640x640 (no detections), 56.0ms
# 13: 640x640 (no detections), 56.0ms
# 14: 640x640 (no detections), 56.0ms
# 15: 640x640 (no detections), 56.0ms
# Speed: 0.0ms preprocess, 56.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56
ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 58.4ms
# 1: 640x640 (no detections), 58.4ms
# 2: 640x640 (no detections), 58.4ms
# 3: 640x640 (no detections), 58.4ms
# 4: 640x640 (no detections), 58.4ms
# 5: 640x640 (no detections), 58.4ms
# 6: 640x640 (no detections), 58.4ms
# 7: 640x640 (no detections), 58.4ms
# 8: 640x640 (no detections), 58.4ms
# 9: 640x640 (no detections), 58.4ms
# 10: 640x640 (no detections), 58.4ms
# 11: 640x640 (no detections), 58.4ms
# 12: 640x640 (no detections), 58.4ms
# 13: 640x640 (no detections), 58.4ms
# 14: 640x640 (no detections), 58.4ms
# 15: 640x640 (no detections), 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 58.3ms
# 1: 640x640 (no detections), 58.3ms
# 2: 640x640 (no detections), 58.3ms
# 3: 640x640 (no detections), 58.3ms
# 4: 640x640 (no detections), 58.3ms
# 5: 640x640 (no detections), 58.3ms
# 6: 640x640 (no detections), 58.3ms
# 7: 640x640 (no detections), 58.3ms
# 8: 640x640 (no detections), 58.3ms
# 9: 640x640 (no detections), 58.3ms
# 10: 640x640 (no detections), 58.3ms
# 11: 640x640 (no detections), 58.3ms
# 12: 640x640 (no detections), 58.3ms
# 13: 640x640 (no detections), 58.3ms
# 14: 640x640 (no detections), 58.3ms
# 15: 640x640 (no detections), 58.3ms
# Speed: 0.0ms preprocess, 58.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 58.3ms
# 1: 640x640 (no detections), 58.3ms
# 2: 640x640 (no detections), 58.3ms
# 3: 640x640 (no detections), 58.3ms
# 4: 640x640 (no detections), 58.3ms
# 5: 640x640 (no detections), 58.3ms
# 6: 640x640 (no detections), 58.3ms
# 7: 640x640 (no detections), 58.3ms
# 8: 640x640 (no detections), 58.3ms
# 9: 640x640 (no detections), 58.3ms
# 10: 640x640 (no detections), 58.3ms
# 11: 640x640 (no detections), 58.3ms
# 12: 640x640 (no detections), 58.3ms
# 13: 640x640 (no detections), 58.3ms
# 14: 640x640 (no detections), 58.3ms
# 15: 640x640 (no detections), 58.3ms
# Speed: 0.0ms preprocess, 58.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 56.2ms
# 1: 640x640 (no detections), 56.2ms
# 2: 640x640 (no detections), 56.2ms
# 3: 640x640 (no detections), 56.2ms
# 4: 640x640 (no detections), 56.2ms
# 5: 640x640 (no detections), 56.2ms
# 6: 640x640 (no detections), 56.2ms
# 7: 640x640 (no detections), 56.2ms
# 8: 640x640 (no detections), 56.2ms
# 9: 640x640 (no detections), 56.2ms
# 10: 640x640 (no detections), 56.2ms
# 11: 640x640 (no detections), 56.2ms
# 12: 640x640 (no detections), 56.2ms
# 13: 640x640 (no detections), 56.2ms
# 14: 640x640 (no detections), 56.2ms
# 15: 640x640 (no detections), 56.2ms
# Speed: 0.0ms preprocess, 56.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 55.9ms
# 1: 640x640 (no detections), 55.9ms
# 2: 640x640 (no detections), 55.9ms
# 3: 640x640 (no detections), 55.9ms
# 4: 640x640 (no detections), 55.9ms
# 5: 640x640 (no detections), 55.9ms
# 6: 640x640 (no detections), 55.9ms
# 7: 640x640 (no detections), 55.9ms
# 8: 640x640 (no detections), 55.9ms
# 9: 640x640 (no detections), 55.9ms
# 10: 640x640 (no detections), 55.9ms
# 11: 640x640 (no detections), 55.9ms
# 12: 640x640 (no detections), 55.9ms
# 13: 640x640 (no detections), 55.9ms
# 14: 640x640 (no detections), 55.9ms
# 15: 640x640 (no detections), 55.9ms
# Speed: 0.0ms preprocess, 55.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 57.2ms
# 1: 640x640 (no detections), 57.2ms
# 2: 640x640 (no detections), 57.2ms
# 3: 640x640 (no detections), 57.2ms
# 4: 640x640 (no detections), 57.2ms
# 5: 640x640 (no detections), 57.2ms
# 6: 640x640 (no detections), 57.2ms
# 7: 640x640 (no detections), 57.2ms
# 8: 640x640 (no detections), 57.2ms
# 9: 640x640 (no detections), 57.2ms
# 10: 640x640 (no detections), 57.2ms
# 11: 640x640 (no detections), 57.2ms
# 12: 640x640 (no detections), 57.2ms
# 13: 640x640 (no detections), 57.2ms
# 14: 640x640 (no detections), 57.2ms
# 15: 640x640 (no detections), 57.2ms
# Speed: 0.0ms preprocess, 57.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 58.3ms
# ...
# 14: 640x640 (no detections), 79.7ms
# 15: 640x640 (no detections), 79.7ms
# Speed: 0.0ms preprocess, 79.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 86.9ms
# 1: 640x640 (no detections), 86.9ms
# 2: 640x640 (no detections), 86.9ms
# 3: 640x640 (no detections), 86.9ms
# 4: 640x640 (no detections), 86.9ms
# 5: 640x640 (no detections), 86.9ms
# 6: 640x640 (no detections), 86.9ms
# 7: 640x640 (no detections), 86.9ms
# 8: 640x640 (no detections), 86.9ms
# 9: 640x640 (no detections), 86.9ms
# 10: 640x640 (no detections), 86.9ms
# 11: 640x640 (no detections), 86.9ms
# 12: 640x640 (no detections), 86.9ms
# 13: 640x640 (no detections), 86.9ms
# 14: 640x640 (no detections), 86.9ms
# 15: 640x640 (no detections), 86.9ms
# Speed: 0.0ms preprocess, 86.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 72.8ms
# 1: 640x640 (no detections), 72.8ms
# 2: 640x640 (no detections), 72.8ms
# 3: 640x640 (no detections), 72.8ms
# 4: 640x640 (no detections), 72.8ms
# 5: 640x640 (no detections), 72.8ms
# 6: 640x640 (no detections), 72.8ms
# 7: 640x640 (no detections), 72.8ms
# 8: 640x640 (no detections), 72.8ms
# 9: 640x640 (no detections), 72.8ms
# 10: 640x640 (no detections), 72.8ms
# 11: 640x640 (no detections), 72.8ms
# 12: 640x640 (no detections), 72.8ms
# 13: 640x640 (no detections), 72.8ms
# 14: 640x640 (no detections), 72.8ms
# 15: 640x640 (no detections), 72.8ms
# Speed: 0.0ms preprocess, 72.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 74.0ms
# 1: 640x640 (no detections), 74.0ms
# 2: 640x640 (no detections), 74.0ms
# 3: 640x640 (no detections), 74.0ms
# 4: 640x640 (no detections), 74.0ms
# 5: 640x640 (no detections), 74.0ms
# 6: 640x640 (no detections), 74.0ms
# 7: 640x640 (no detections), 74.0ms
# 8: 640x640 (no detections), 74.0ms
# 9: 640x640 (no detections), 74.0ms
# 10: 640x640 (no detections), 74.0ms
# 11: 640x640 (no detections), 74.0ms
# 12: 640x640 (no detections), 74.0ms
# 13: 640x640 (no detections), 74.0ms
# 14: 640x640 (no detections), 74.0ms
# 15: 640x640 (no detections), 74.0ms
# Speed: 0.0ms preprocess, 74.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 75.4ms
# 1: 640x640 (no detections), 75.4ms
# 2: 640x640 (no detections), 75.4ms
# 3: 640x640 (no detections), 75.4ms
# 4: 640x640 (no detections), 75.4ms
# 5: 640x640 (no detections), 75.4ms
# 6: 640x640 (no detections), 75.4ms
# 7: 640x640 (no detections), 75.4ms
# 8: 640x640 (no detections), 75.4ms
# 9: 640x640 (no detections), 75.4ms
# 10: 640x640 (no detections), 75.4ms
# 11: 640x640 (no detections), 75.4ms
# 12: 640x640 (no detections), 75.4ms
# 13: 640x640 (no detections), 75.4ms
# 14: 640x640 (no detections), 75.4ms
# 15: 640x640 (no detections), 75.4ms
# Speed: 0.0ms preprocess, 75.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 73.8ms
# 1: 640x640 (no detections), 73.8ms
# 2: 640x640 (no detections), 73.8ms
# 3: 640x640 (no detections), 73.8ms
# 4: 640x640 (no detections), 73.8ms
# 5: 640x640 (no detections), 73.8ms
# 6: 640x640 (no detections), 73.8ms
# 7: 640x640 (no detections), 73.8ms
# 8: 640x640 (no detections), 73.8ms
# 9: 640x640 (no detections), 73.8ms
# 10: 640x640 (no detections), 73.8ms
# 11: 640x640 (no detections), 73.8ms
# 12: 640x640 (no detections), 73.8ms
# 13: 640x640 (no detections), 73.8ms
# 14: 640x640 (no detections), 73.8ms
# 15: 640x640 (no detections), 73.8ms
# Speed: 0.0ms preprocess, 73.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 82.5ms
# 1: 640x640 (no detections), 82.5ms
# 2: 640x640 (no detections), 82.5ms
# 3: 640x640 (no detections), 82.5ms
# 4: 640x640 (no detections), 82.5ms
# 5: 640x640 (no detections), 82.5ms
# 6: 640x640 (no detections), 82.5ms
# 7: 640x640 (no detections), 82.5ms
# 8: 640x640 (no detections), 82.5ms
# 9: 640x640 (no detections), 82.5ms
# 10: 640x640 (no detections), 82.5ms
# 11: 640x640 (no detections), 82.5ms
# 12: 640x640 (no detections), 82.5ms
# 13: 640x640 (no detections), 82.5ms
# 14: 640x640 (no detections), 82.5ms
# 15: 640x640 (no detections), 82.5ms
# Speed: 0.0ms preprocess, 82.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 79.9ms
# 1: 640x640 (no detections), 79.9ms
# 2: 640x640 (no detections), 79.9ms
# 3: 640x640 (no detections), 79.9ms
# 4: 640x640 (no detections), 79.9ms
# 5: 640x640 (no detections), 79.9ms
# 6: 640x640 (no detections), 79.9ms
# 7: 640x640 (no detections), 79.9ms
# 8: 640x640 (no detections), 79.9ms
# 9: 640x640 (no detections), 79.9ms
# 10: 640x640 (no detections), 79.9ms
# 11: 640x640 (no detections), 79.9ms
# 12: 640x640 (no detections), 79.9ms
# 13: 640x640 (no detections), 79.9ms
# 14: 640x640 (no detections), 79.9ms
# 15: 640x640 (no detections), 79.9ms
# Speed: 0.0ms preprocess, 79.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 75.2ms
# 1: 640x640 (no detections), 75.2ms
# 2: 640x640 (no detections), 75.2ms
# 3: 640x640 (no detections), 75.2ms
# 4: 640x640 (no detections), 75.2ms
# 5: 640x640 (no detections), 75.2ms
# 6: 640x640 (no detections), 75.2ms
# 7: 640x640 (no detections), 75.2ms
# 8: 640x640 (no detections), 75.2ms
# 9: 640x640 (no detections), 75.2ms
# 10: 640x640 (no detections), 75.2ms
# 11: 640x640 (no detections), 75.2ms
# 12: 640x640 (no detections), 75.2ms
# 13: 640x640 (no detections), 75.2ms
# 14: 640x640 (no detections), 75.2ms
# 15: 640x640 (no detections), 75.2ms
# Speed: 0.0ms preprocess, 75.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 84.3ms
# 1: 640x640 (no detections), 84.3ms
# 2: 640x640 (no detections), 84.3ms
# 3: 640x640 (no detections), 84.3ms
# 4: 640x640 (no detections), 84.3ms
# 5: 640x640 (no detections), 84.3ms
# 6: 640x640 (no detections), 84.3ms
# 7: 640x640 (no detections), 84.3ms
# 8: 640x640 (no detections), 84.3ms
# 9: 640x640 (no detections), 84.3ms
# 10: 640x640 (no detections), 84.3ms
# 11: 640x640 (no detections), 84.3ms
# 12: 640x640 (no detections), 84.3ms
# 13: 640x640 (no detections), 84.3ms
# 14: 640x640 (no detections), 84.3ms
# 15: 640x640 (no detections), 84.3ms
# Speed: 0.0ms preprocess, 84.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 86.1ms
# 1: 640x640 (no detections), 86.1ms
# 2: 640x640 (no detections), 86.1ms
# 3: 640x640 (no detections), 86.1ms
# 4: 640x640 (no detections), 86.1ms
# 5: 640x640 (no detections), 86.1ms
# 6: 640x640 (no detections), 86.1ms
# 7: 640x640 (no detections), 86.1ms
# 8: 640x640 (no detections), 86.1ms
# 9: 640x640 (no detections), 86.1ms
# 10: 640x640 (no detections), 86.1ms
# 11: 640x640 (no detections), 86.1ms
# 12: 640x640 (no detections), 86.1ms
# 13: 640x640 (no detections), 86.1ms
# 14: 640x640 (no detections), 86.1ms
# 15: 640x640 (no detections), 86.1ms
# Speed: 0.0ms preprocess, 86.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 80.7ms
# 1: 640x640 (no detections), 80.7ms
# 2: 640x640 (no detections), 80.7ms
# 3: 640x640 (no detections), 80.7ms
# 4: 640x640 (no detections), 80.7ms
# 5: 640x640 (no detections), 80.7ms
# 6: 640x640 (no detections), 80.7ms
# 7: 640x640 (no detections), 80.7ms
# 8: 640x640 (no detections), 80.7ms
# 9: 640x640 (no detections), 80.7ms
# 10: 640x640 (no detections), 80.7ms
# 11: 640x640 (no detections), 80.7ms
# 12: 640x640 (no detections), 80.7ms
# 13: 640x640 (no detections), 80.7ms
# 14: 640x640 (no detections), 80.7ms
# 15: 640x640 (no detections), 80.7ms
# Speed: 0.0ms preprocess, 80.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 76.4ms
# 1: 640x640 (no detections), 76.4ms
# 2: 640x640 (no detections), 76.4ms
# 3: 640x640 (no detections), 76.4ms
# 4: 640x640 (no detections), 76.4ms
# 5: 640x640 (no detections), 76.4ms
# 6: 640x640 (no detections), 76.4ms
# 7: 640x640 (no detections), 76.4ms
# 8: 640x640 (no detections), 76.4ms
# 9: 640x640 (no detections), 76.4ms
# 10: 640x640 (no detections), 76.4ms
# 11: 640x640 (no detections), 76.4ms
# 12: 640x640 (no detections), 76.4ms
# 13: 640x640 (no detections), 76.4ms
# 14: 640x640 (no detections), 76.4ms
# 15: 640x640 (no detections), 76.4ms
# Speed: 0.0ms preprocess, 76.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 78.0ms
# 1: 640x640 (no detections), 78.0ms
# 2: 640x640 (no detections), 78.0ms
# 3: 640x640 (no detections), 78.0ms
# 4: 640x640 (no detections), 78.0ms
# 5: 640x640 (no detections), 78.0ms
# 6: 640x640 (no detections), 78.0ms
# 7: 640x640 (no detections), 78.0ms
# 8: 640x640 (no detections), 78.0ms
# 9: 640x640 (no detections), 78.0ms
# 10: 640x640 (no detections), 78.0ms
# 11: 640x640 (no detections), 78.0ms
# 12: 640x640 (no detections), 78.0ms
# 13: 640x640 (no detections), 78.0ms
# 14: 640x640 (no detections), 78.0ms
# 15: 640x640 (no detections), 78.0ms
# Speed: 0.0ms preprocess, 78.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 82.3ms
# 1: 640x640 (no detections), 82.3ms
# 2: 640x640 (no detections), 82.3ms
# 3: 640x640 (no detections), 82.3ms
# 4: 640x640 (no detections), 82.3ms
# 5: 640x640 (no detections), 82.3ms
# 6: 640x640 (no detections), 82.3ms
# 7: 640x640 (no detections), 82.3ms
# 8: 640x640 (no detections), 82.3ms
# 9: 640x640 (no detections), 82.3ms
# 10: 640x640 (no detections), 82.3ms
# 11: 640x640 (no detections), 82.3ms
# 12: 640x640 (no detections), 82.3ms
# 13: 640x640 (no detections), 82.3ms
# 14: 640x640 (no detections), 82.3ms
# 15: 640x640 (no detections), 82.3ms
# Speed: 0.0ms preprocess, 82.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 85.5ms
# 1: 640x640 (no detections), 85.5ms
# 2: 640x640 (no detections), 85.5ms
# 3: 640x640 (no detections), 85.5ms
# 4: 640x640 (no detections), 85.5ms
# 5: 640x640 (no detections), 85.5ms
# 6: 640x640 (no detections), 85.5ms
# 7: 640x640 (no detections), 85.5ms
# 8: 640x640 (no detections), 85.5ms
# 9: 640x640 (no detections), 85.5ms
# 10: 640x640 (no detections), 85.5ms
# 11: 640x640 (no detections), 85.5ms
# 12: 640x640 (no detections), 85.5ms
# 13: 640x640 (no detections), 85.5ms
# 14: 640x640 (no detections), 85.5ms
# 15: 640x640 (no detections), 85.5ms
# Speed: 0.0ms preprocess, 85.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 77.6ms
# 1: 640x640 (no detections), 77.6ms
# 2: 640x640 (no detections), 77.6ms
# 3: 640x640 (no detections), 77.6ms
# 4: 640x640 (no detections), 77.6ms
# 5: 640x640 (no detections), 77.6ms
# 6: 640x640 (no detections), 77.6ms
# 7: 640x640 (no detections), 77.6ms
# 8: 640x640 (no detections), 77.6ms
# 9: 640x640 (no detections), 77.6ms
# 10: 640x640 (no detections), 77.6ms
# 11: 640x640 (no detections), 77.6ms
# 12: 640x640 (no detections), 77.6ms
# 13: 640x640 (no detections), 77.6ms
# 14: 640x640 (no detections), 77.6ms
# 15: 640x640 (no detections), 77.6ms
# Speed: 0.0ms preprocess, 77.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 77.5ms
# 1: 640x640 (no detections), 77.5ms
# 2: 640x640 (no detections), 77.5ms
# 3: 640x640 (no detections), 77.5ms
# 4: 640x640 (no detections), 77.5ms
# 5: 640x640 (no detections), 77.5ms
# 6: 640x640 (no detections), 77.5ms
# 7: 640x640 (no detections), 77.5ms
# 8: 640x640 (no detections), 77.5ms
# 9: 640x640 (no detections), 77.5ms
# 10: 640x640 (no detections), 77.5ms
# 11: 640x640 (no detections), 77.5ms
# 12: 640x640 (no detections), 77.5ms
# 13: 640x640 (no detections), 77.5ms
# 14: 640x640 (no detections), 77.5ms
# 15: 640x640 (no detections), 77.5ms
# Speed: 0.0ms preprocess, 77.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 117
#     113         process_video_on_gpu(video["input"], video["output"], video["csv"])
#     116 if __name__ == "__main__":
# --> 117     main()
#
# Cell In[2], line 113, in main()
#      99 videos = [
#     100     {"input": "video (1).mp4", "output": "output (1).mp4", "csv": "output (1).csv"},
#     101     {"input": "video (2).mp4", "output": "output (2).mp4", "csv": "output (2).csv"},
#    (...)
#     109     {"input": "video (10).mp4", "output": "output (10).mp4", "csv": "output (10).csv"}
#     110 ]
#     112 for video in videos:
# --> 113     process_video_on_gpu(video["input"], video["output"], video["csv"])
#
# Cell In[2], line 42, in process_video_on_gpu(video_path, output_path, csv_file, batch_size)
#      40     # Process frames in batches
#      41     if len(frames_batch) == batch_size:
# ---> 42         process_batch(frames_batch, current_time, model, out, csv_file, people_counts)
#      43         frames_batch = []
#      45 # Process remaining frames
#
# Cell In[2], line 76, in process_batch(frames_batch, current_time, model, out, csv_file, people_counts)
#      73 batch_tensor = torch.cat(frames_tensor) / 255.0  # Normalize the images
#      75 # Run YOLO inference
# ---> 76 results = model(batch_tensor)
#      78 for i, frame in enumerate(frames_batch):
#      79     # Extract people detections for each frame
#      80     people_count = sum(1 for detection in results[i].boxes if int(detection.cls) == 0)
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:180, in Model.__call__(self, source, stream, **kwargs)
#     151 def __call__(
#     152     self,
#     153     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     154     stream: bool = False,
#     155     **kwargs: Any,
#     156 ) -> list:
#     157     """
#     158     Alias for the predict method, enabling the model instance to be callable for predictions.
#     159
#    (...)
#     178         ...     print(f"Detected {len(r)} objects in image")
#     179     """
# --> 180     return self.predict(source, stream, **kwargs)
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/ultralytics/engine/model.py:558, in Model.predict(self, source, stream, predictor, **kwargs)
#     556 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     557     self.predictor.set_prompts(prompts)
# --> 558 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:173, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     171     return self.stream_inference(source, model, *args, **kwargs)
#     172 else:
# --> 173     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/ultralytics/engine/predictor.py:258, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     255     im = self.preprocess(im0s)
#     257 # Inference
# --> 258 with profilers[1]:
#     259     preds = self.inference(im, *args, **kwargs)
#     260     if self.args.embed:
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/ultralytics/utils/ops.py:51, in Profile.__exit__(self, type, value, traceback)
#      49 def __exit__(self, type, value, traceback):  # noqa
#      50     """Stop timing."""
# ---> 51     self.dt = self.time() - self.start  # delta-time
#      52     self.t += self.dt
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/ultralytics/utils/ops.py:61, in Profile.time(self)
#      59 """Get current time."""
#      60 if self.cuda:
# ---> 61     torch.cuda.synchronize(self.device)
#      62 return time.time()
#
# File /mnt/e/Documents/VCB/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:954, in synchronize(device)
#     952 _lazy_init()
#     953 with torch.cuda.device(device):
# --> 954     return torch._C._cuda_synchronize()
#
# KeyboardInterrupt:
